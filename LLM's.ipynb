# %% [markdown]
# LLM -> Chatgpt ... before understanding that lets see the history of the seq2seq models
#
# We have seen before Seq 2 Seq model ... their types -> many-to-one, one-to-many, one-to-one, many-to-many .
#
# So lets see some popular application other than machine translation of many-to-many seq-to-seq model
# ![lec_img/seq2seq.png](lec_img/seq2seq.png)

# %% [markdown]
# ![lec_img/seq2seq_flow.png](lec_img/seq2seq_flow.png)

# %% [markdown]
# Stage 1 ->
#
#     - The Encoder-Decoder architecture given by
